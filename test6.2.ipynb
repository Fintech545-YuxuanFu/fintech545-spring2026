# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/fuyuxuan/Downloads/test6.csv")
df["Date"] = pd.to_datetime(df["Date"])
df = df.set_index("Date")

log_return = np.log(df / df.shift(1)).iloc[1:]
print(log_return)
# Out:
#                  SPY      AAPL      MSFT      AMZN      NVDA     GOOGL  \
# Date
# 2022-09-02 -0.010600 -0.013705 -0.016807 -0.002428 -0.021027 -0.017373
# 2022-09-06 -0.003780 -0.008249 -0.011035 -0.011040 -0.013426 -0.009690
# 2022-09-07  0.017806  0.009211  0.018931  0.026372  0.018621  0.024416
# 2022-09-08  0.006515 -0.009664  0.001665  0.002623  0.019926 -0.009824
# 2022-09-09  0.015416  0.018664  0.022717  0.026228  0.027982  0.020729
# ...              ...       ...       ...       ...       ...       ...
# 2023-09-18  0.000586  0.016772 -0.003519 -0.002925  0.001502  0.005878
# 2023-09-19 -0.002076  0.006162 -0.001247 -0.016931 -0.010196 -0.001231
# 2023-09-20 -0.009236 -0.020195 -0.024269 -0.017148 -0.029877 -0.031646
# 2023-09-21 -0.016666 -0.008929 -0.003873 -0.045053 -0.029357 -0.024984
# 2023-09-22 -0.002251  0.004932 -0.007918 -0.001625  0.014354 -0.001458
#
#                 TSLA      GOOG     BRK-B      META  ...        CI       ETN  \
# ...
