# %%
import numpy as np
import pandas as pd

# %%
# Load data
cov_input = pd.read_csv("/Users/fuyuxuan/Downloads/test5_1.csv")
number_of_simulations = 100000

np.random.seed(0)

# Convert it to numpy array
cov_matrix = cov_input.values

# Zero mean vector
mu = np.zeros(cov_matrix.shape[0])

# Simulate multivariate normal draws
simulated_data = np.random.multivariate_normal(mu, cov_matrix, number_of_simulations)

# Compute output covariance matrix
cov_output = np.cov(simulated_data, rowvar=False)

# Convert it to DataFrame
cov_output_df = pd.DataFrame(cov_output, columns=cov_input.columns, index=cov_input.columns)

print(cov_output_df)
# Out:
#           x1        x2        x3        x4        x5
# x1  0.084657  0.087037  0.042087  0.008959  0.003873
# x2  0.087037  0.159460  0.057836  0.012264  0.005316
# x3  0.042087  0.057836  0.037381  0.005959  0.002571
# x4  0.008959  0.012264  0.005959  0.001687  0.000546
# x5  0.003873  0.005316  0.002571  0.000546  0.000314
