# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/fuyuxuan/Downloads/test6.csv")
df["Date"] = pd.to_datetime(df["Date"])
df = df.set_index("Date")

arith_return = (df / df.shift(1) - 1).iloc[1:]
print(arith_return)
# Out:
#                  SPY      AAPL      MSFT      AMZN      NVDA     GOOGL  \
# Date
# 2022-09-02 -0.010544 -0.013611 -0.016667 -0.002425 -0.020808 -0.017223
# 2022-09-06 -0.003773 -0.008215 -0.010974 -0.010980 -0.013336 -0.009643
# 2022-09-07  0.017965  0.009254  0.019111  0.026723  0.018795  0.024717
# 2022-09-08  0.006536 -0.009618  0.001666  0.002626  0.020126 -0.009776
# 2022-09-09  0.015535  0.018840  0.022977  0.026575  0.028377  0.020945
# ...              ...       ...       ...       ...       ...       ...
# 2023-09-18  0.000586  0.016913 -0.003513 -0.002920  0.001503  0.005895
# 2023-09-19 -0.002074  0.006181 -0.001246 -0.016788 -0.010144 -0.001230
# 2023-09-20 -0.009193 -0.019992 -0.023977 -0.017002 -0.029435 -0.031150
# 2023-09-21 -0.016528 -0.008889 -0.003866 -0.044053 -0.028931 -0.024675
# 2023-09-22 -0.002249  0.004945 -0.007887 -0.001624  0.014457 -0.001457
#
#                 TSLA      GOOG     BRK-B      META  ...        CI       ETN  \
# ...
